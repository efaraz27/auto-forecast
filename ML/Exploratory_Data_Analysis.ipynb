# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Dataset Overview

# %%
# %pip install pandas matplotlib seaborn
# Out:
# Requirement already satisfied: pandas in /Users/efaraz27/Desktop/Projects/car-price-prediction/.venv/lib/python3.10/site-packages (2.1.3)
# Collecting matplotlib
#   Using cached matplotlib-3.8.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting seaborn
#   Using cached seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in /Users/efaraz27/Desktop/Projects/car-price-prediction/.venv/lib/python3.10/site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/efaraz27/Desktop/Projects/car-price-prediction/.venv/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/efaraz27/Desktop/Projects/car-price-prediction/.venv/lib/python3.10/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /Users/efaraz27/Desktop/Projects/car-price-prediction/.venv/lib/python3.10/site-packages (from pandas) (2023.3)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Using cached contourpy-1.2.1-cp310-cp310-macosx_11_0_arm64.whl.metadata (5.8 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Using cached fonttools-4.51.0-cp310-cp310-macosx_10_9_universal2.whl.metadata (159 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Using cached kiwisolver-1.4.5-cp310-cp310-macosx_11_0_arm64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/efaraz27/Desktop/Projects/car-price-prediction/.venv/lib/python3.10/site-packages (from matplotlib) (24.0)
# Collecting pillow>=8 (from matplotlib)
#   Using cached pillow-10.3.0-cp310-cp310-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Using cached pyparsing-3.1.2-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: six>=1.5 in /Users/efaraz27/Desktop/Projects/car-price-prediction/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Using cached matplotlib-3.8.4-cp310-cp310-macosx_11_0_arm64.whl (7.5 MB)
# Using cached seaborn-0.13.2-py3-none-any.whl (294 kB)
# Using cached contourpy-1.2.1-cp310-cp310-macosx_11_0_arm64.whl (244 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.51.0-cp310-cp310-macosx_10_9_universal2.whl (2.8 MB)
# Using cached kiwisolver-1.4.5-cp310-cp310-macosx_11_0_arm64.whl (66 kB)
# Using cached pillow-10.3.0-cp310-cp310-macosx_11_0_arm64.whl (3.4 MB)
# Using cached pyparsing-3.1.2-py3-none-any.whl (103 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib, seaborn
# Successfully installed contourpy-1.2.1 cycler-0.12.1 fonttools-4.51.0 kiwisolver-1.4.5 matplotlib-3.8.4 pillow-10.3.0 pyparsing-3.1.2 seaborn-0.13.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
data = pd.read_csv('Data_Train.csv')
data.head()
# Out:
#                                Name    Location  Year  Kilometers_Driven  \
# 0            Maruti Wagon R LXI CNG      Mumbai  2010              72000
# 1  Hyundai Creta 1.6 CRDi SX Option        Pune  2015              41000
# 2                      Honda Jazz V     Chennai  2011              46000
# 3                 Maruti Ertiga VDI     Chennai  2012              87000
# 4   Audi A4 New 2.0 TDI Multitronic  Coimbatore  2013              40670
#
#   Fuel_Type Transmission Owner_Type     Mileage   Engine      Power  Seats  \
# 0       CNG       Manual      First  26.6 km/kg   998 CC  58.16 bhp    5.0
# 1    Diesel       Manual      First  19.67 kmpl  1582 CC  126.2 bhp    5.0
# 2    Petrol       Manual      First   18.2 kmpl  1199 CC   88.7 bhp    5.0
# 3    Diesel       Manual      First  20.77 kmpl  1248 CC  88.76 bhp    7.0
# 4    Diesel    Automatic     Second   15.2 kmpl  1968 CC  140.8 bhp    5.0
#
#    Price
# 0   1.75
# 1  12.50
# 2   4.50
# 3   6.00
# 4  17.74

# %% [markdown]
# ## Data Summary

# %%
# Data types of columns
print(f"Data types of data columns: \n{data.dtypes}")
# Out:
# Data types of data columns:
# Name                  object
# Location              object
# Year                   int64
# Kilometers_Driven      int64
# Fuel_Type             object
# Transmission          object
# Owner_Type            object
# Mileage               object
# Engine                object
# Power                 object
# Seats                float64
# Price                float64
# dtype: object

# %%
data.describe()
# Out:
#               Year  Kilometers_Driven        Seats        Price
# count  6019.000000       6.019000e+03  5977.000000  6019.000000
# mean   2013.358199       5.873838e+04     5.278735     9.479468
# std       3.269742       9.126884e+04     0.808840    11.187917
# min    1998.000000       1.710000e+02     0.000000     0.440000
# 25%    2011.000000       3.400000e+04     5.000000     3.500000
# 50%    2014.000000       5.300000e+04     5.000000     5.640000
# 75%    2016.000000       7.300000e+04     5.000000     9.950000
# max    2019.000000       6.500000e+06    10.000000   160.000000

# %% [markdown]
# ## Data Visualizations

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create a figure to hold the visualizations
fig, axes = plt.subplots(6, 1, figsize=(10, 30))

# Histogram of Price
sns.histplot(data=data, x='Price', kde=True, ax=axes[0])
axes[0].set_title('Distribution of Price')

# Histogram of Kilometers Driven
sns.histplot(data=data, x='Kilometers_Driven', kde=True, ax=axes[1])
axes[1].set_title('Distribution of Kilometers Driven')

# Boxplot of Price vs Fuel Type
sns.boxplot(x='Fuel_Type', y='Price', data=data, ax=axes[2])
axes[2].set_title('Price vs Fuel Type')

# Scatterplot of Price vs Year
sns.scatterplot(x='Year', y='Price', data=data, ax=axes[3])
axes[3].set_title('Price vs Year')

# Scatterplot of Price vs Engine Size
sns.scatterplot(x='Engine', y='Price', data=data, ax=axes[4])
axes[4].set_title('Price vs Engine Size')

# Scatterplot of Price vs Power
sns.scatterplot(x='Power', y='Price', data=data, ax=axes[5])
axes[5].set_title('Price vs Power')

# Adjust the spacing between subplots
plt.tight_layout()



# export a4 size images in landscape mode
plt.savefig('output.png', dpi=300, orientation='landscape')

# Show the individual graphs
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set the aesthetics for the plots
sns.set(style="whitegrid")

# Create a figure to hold the visualizations
fig, axes = plt.subplots(3, 2, figsize=(14, 18))

# Histogram of Price
sns.histplot(data=data, x='Price', kde=True, ax=axes[0, 0])
axes[0, 0].set_title('Distribution of Price')

# Histogram of Kilometers Driven
sns.histplot(data=data, x='Kilometers_Driven', kde=True, ax=axes[0, 1])
axes[0, 1].set_title('Distribution of Kilometers Driven')

# Boxplot of Price vs Fuel Type
sns.boxplot(x='Fuel_Type', y='Price', data=data, ax=axes[1, 0])
axes[1, 0].set_title('Price vs Fuel Type')

# Scatterplot of Price vs Year
sns.scatterplot(x='Year', y='Price', data=data, ax=axes[1, 1])
axes[1, 1].set_title('Price vs Year')

# Scatterplot of Price vs Engine Size
sns.scatterplot(x='Engine', y='Price', data=data, ax=axes[2, 0])
axes[2, 0].set_title('Price vs Engine Size')

# Scatterplot of Price vs Power
sns.scatterplot(x='Power', y='Price', data=data, ax=axes[2, 1])
axes[2, 1].set_title('Price vs Power')

plt.tight_layout()
plt.show()
